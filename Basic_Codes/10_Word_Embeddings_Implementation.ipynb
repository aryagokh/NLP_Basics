# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'your videos are good',
]
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
vocab_size = 10000

# %%
# One Hot Representation
one_hot_repr = [one_hot(word, vocab_size) for word in sent]
one_hot_repr
# Out:
# [[7617, 6967, 7642, 5198],
#  [7617, 6967, 7642, 9678],
#  [7617, 136, 7642, 9923],
#  [430, 1495, 7364, 6282, 9774],
#  [430, 1495, 7364, 6282, 2587],
#  [370, 7617, 2635, 7642, 6476],
#  [1004, 643, 6729, 6282]]

# %%
# Word Embedding Representation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
sent_len = 8
embedded_docs = pad_sequences(one_hot_repr, padding='post', maxlen=sent_len)

# %%
embedded_docs
# Out:
# array([[7617, 6967, 7642, 5198,    0,    0,    0,    0],
#        [7617, 6967, 7642, 9678,    0,    0,    0,    0],
#        [7617,  136, 7642, 9923,    0,    0,    0,    0],
#        [ 430, 1495, 7364, 6282, 9774,    0,    0,    0],
#        [ 430, 1495, 7364, 6282, 2587,    0,    0,    0],
#        [ 370, 7617, 2635, 7642, 6476,    0,    0,    0],
#        [1004,  643, 6729, 6282,    0,    0,    0,    0]])

# %%
# Feature representation
dim=10
model = Sequential()
model.add(Embedding(vocab_size, dim, input_length=sent_len))
model.compile('adam', 'mse')
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_8 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# array([[[ 0.01070546, -0.02263305,  0.01851267,  0.01484132,
#           0.00076663, -0.00440445,  0.01098203,  0.04474363,
#          -0.01514395, -0.01562247],
#         [-0.00673719,  0.04473844,  0.00567924,  0.00138294,
#           0.00561714, -0.02721819, -0.04617926, -0.03235753,
#           0.0141839 , -0.04534069],
#         [ 0.00545368,  0.02241813, -0.01324613, -0.01285814,
#           0.04204741,  0.03542416, -0.04187076, -0.03134488,
#          -0.01443453, -0.03561477],
#         [ 0.03490194,  0.02810786, -0.0134547 , -0.04081251,
#           0.04111392, -0.04852823,  0.04624898,  0.03796034,
#           0.01696585,  0.01692501],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ]],
#
#        [[ 0.01070546, -0.02263305,  0.01851267,  0.01484132,
#           0.00076663, -0.00440445,  0.01098203,  0.04474363,
#          -0.01514395, -0.01562247],
#         [-0.00673719,  0.04473844,  0.00567924,  0.00138294,
#           0.00561714, -0.02721819, -0.04617926, -0.03235753,
#           0.0141839 , -0.04534069],
#         [ 0.00545368,  0.02241813, -0.01324613, -0.01285814,
#           0.04204741,  0.03542416, -0.04187076, -0.03134488,
#          -0.01443453, -0.03561477],
#         [-0.011307  ,  0.04127607, -0.0467012 ,  0.00723876,
#           0.0309624 ,  0.04275378,  0.03051538,  0.04249689,
#           0.01012396, -0.00224391],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ]],
#
#        [[ 0.01070546, -0.02263305,  0.01851267,  0.01484132,
#           0.00076663, -0.00440445,  0.01098203,  0.04474363,
#          -0.01514395, -0.01562247],
#         [-0.00860318,  0.02698335,  0.01319097, -0.03830248,
#           0.01376951, -0.04483472, -0.01385885, -0.03344433,
#           0.04348304,  0.00630466],
#         [ 0.00545368,  0.02241813, -0.01324613, -0.01285814,
#           0.04204741,  0.03542416, -0.04187076, -0.03134488,
#          -0.01443453, -0.03561477],
#         [-0.0216512 ,  0.00106414,  0.0048799 ,  0.02056085,
#          -0.0429948 ,  0.02803263,  0.03464529,  0.01684796,
#           0.00040894, -0.01044358],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ]],
#
#        [[ 0.0278498 , -0.00855755, -0.03957291, -0.01681861,
#           0.01293291, -0.04074571,  0.0487528 , -0.03316983,
#          -0.02108576, -0.00582112],
#         [-0.03568297, -0.03301108,  0.01409364,  0.03001406,
#           0.01333663, -0.03252188,  0.00017221,  0.04549162,
#           0.01538504, -0.01361258],
#         [ 0.01741597,  0.01909287,  0.00649916, -0.04675102,
#          -0.01859314, -0.0262583 ,  0.00798349, -0.01763393,
#           0.02921779, -0.02349414],
#         [-0.04535686,  0.01804086,  0.04892817,  0.02663482,
#          -0.00769067,  0.0210176 ,  0.04659411,  0.01032313,
#          -0.04093879,  0.02326219],
#         [ 0.00780178, -0.00699881, -0.03362133, -0.01247694,
#          -0.01042017,  0.01955012,  0.04054077, -0.04576764,
#           0.0485652 ,  0.02205542],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ]],
#
#        [[ 0.0278498 , -0.00855755, -0.03957291, -0.01681861,
#           0.01293291, -0.04074571,  0.0487528 , -0.03316983,
#          -0.02108576, -0.00582112],
#         [-0.03568297, -0.03301108,  0.01409364,  0.03001406,
#           0.01333663, -0.03252188,  0.00017221,  0.04549162,
#           0.01538504, -0.01361258],
#         [ 0.01741597,  0.01909287,  0.00649916, -0.04675102,
#          -0.01859314, -0.0262583 ,  0.00798349, -0.01763393,
#           0.02921779, -0.02349414],
#         [-0.04535686,  0.01804086,  0.04892817,  0.02663482,
#          -0.00769067,  0.0210176 ,  0.04659411,  0.01032313,
#          -0.04093879,  0.02326219],
#         [-0.0350319 , -0.0367173 ,  0.0233265 , -0.02896777,
#          -0.03188862, -0.03880308, -0.02977246, -0.01292004,
#           0.01010083,  0.03578707],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ]],
#
#        [[ 0.02541328, -0.01494628,  0.01303189,  0.04019152,
#           0.01319603, -0.04010351, -0.02989237, -0.02050236,
#          -0.02674973, -0.04943919],
#         [ 0.01070546, -0.02263305,  0.01851267,  0.01484132,
#           0.00076663, -0.00440445,  0.01098203,  0.04474363,
#          -0.01514395, -0.01562247],
#         [ 0.03765451,  0.01215564,  0.01953359, -0.01745343,
#          -0.03132041,  0.0471408 ,  0.00229704,  0.02425348,
#          -0.00343349, -0.04214378],
#         [ 0.00545368,  0.02241813, -0.01324613, -0.01285814,
#           0.04204741,  0.03542416, -0.04187076, -0.03134488,
#          -0.01443453, -0.03561477],
#         [ 0.02827616, -0.0132789 ,  0.02820358, -0.01598024,
#          -0.02882227, -0.02001431, -0.02143885, -0.01420693,
#          -0.01717009,  0.03216285],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ]],
#
#        [[ 0.01250518, -0.03808681,  0.00266067, -0.00066245,
#          -0.0227402 ,  0.00104644, -0.01939681, -0.03215652,
#          -0.03439309,  0.00022106],
#         [-0.01886275,  0.01835731,  0.03219158,  0.03579179,
#           0.04166708, -0.04434621,  0.00605197, -0.02826995,
#          -0.04306832,  0.0366876 ],
#         [ 0.03966515, -0.02328211,  0.01965382,  0.04244045,
#           0.04011874,  0.03019662, -0.02392092,  0.01008803,
#          -0.00076234,  0.00335755],
#         [-0.04535686,  0.01804086,  0.04892817,  0.02663482,
#          -0.00769067,  0.0210176 ,  0.04659411,  0.01032313,
#          -0.04093879,  0.02326219],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ],
#         [-0.03973708, -0.03619694, -0.04332435, -0.00347615,
#          -0.02357861, -0.00446498, -0.04731046,  0.00013564,
#           0.02397778,  0.0372696 ]]], dtype=float32)
